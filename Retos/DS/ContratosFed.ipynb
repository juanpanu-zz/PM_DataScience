# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import ijson

# %%
filename = "./db/contratacionesabiertas_bulk.json"
with open(filename, 'r',encoding='utf8') as f:
    objects = ijson.items(f, '_id.')
    columns = list(objects)

# %%
print(columns[0])
# Out:
# {'_id': {'$oid': '5e2a3797575b631d3c62539e'}, 'publisher': {'uid': '6716', 'name': 'SECRETARÍA DE HACIENDA Y CRÉDITO PÚBLICO', 'uri': 'http://www.gob.mx/shcp'}, 'cycle': 2016, 'ocid': 'ocds-07smqs-1003123', 'id': 'SHCP-1003123-2018-11-12', 'date': '2016-02-19T01:49:22Z', 'tag': ['tender', 'award'], 'initiationType': 'tender', 'parties': [{'name': 'Procuraduría General de la República', 'id': 'PGR-251', 'roles': ['buyer']}, {'name': 'PGR-DELEGACION EN EL DISTRITO FEDERAL #017000017', 'id': 'PGR850101RC6-017000017', 'identifier': {'id': 'PGR850101RC6-017000017', 'legalName': 'PGR-DELEGACION EN EL DISTRITO FEDERAL #017000017', 'scheme': 'MX-RFC', 'uri': 'https://portalsat.plataforma.sat.gob.mx/ConsultaRFC'}, 'address': {'streetAddress': 'Dr. Carmona y Valle 150', 'locality': 'Cuauhtémoc', 'region': 'Ciudad de México', 'postalCode': '06720', 'countryName': 'MX'}, 'contactPoint': {'name': 'Ignacio Romero Sánchez', 'email': 'martin.montero@pgr.gob.mx', 'telephone': '53463611'}, 'roles': ['
# ...

# %%
column_names = [col["_id"] for col in columns]
column_names
# Out:
# e2a37a601df421dc14ff16f'},
#  {'$oid': '5e2a37a687a0271509adc8a5'},
#  {'$oid': '5e2a37a639415ef7cdf452f6'},
#  {'$oid': '5e2a37a61777f3ae47515fa7'},
#  {'$oid': '5e2a37a785fd901de345a4a5'},
#  {'$oid': '5e2a37a7e115b6320bf4a0ac'},
#  {'$oid': '5e2a37a75c728898e5be22cc'},
#  {'$oid': '5e2a37a750e9aa87fd5143c2'},
#  {'$oid': '5e2a37a77c314be96f409b39'},
#  {'$oid': '5e2a37a71c1a2a0300896de7'},
#  {'$oid': '5e2a37a7224ebfb082dd7f69'},
#  {'$oid': '5e2a37a77d72101d1819ac0c'},
#  {'$oid': '5e2a37a7ae8c3725b9fa2df2'},
#  {'$oid': '5e2a37a7a9dbec6b37755838'},
#  {'$oid': '5e2a37a766f4235687a34b5e'},
#  {'$oid': '5e2a37a767de2dd5018a9a3c'},
#  {'$oid': '5e2a37a7ef03159d34b9e489'},
#  {'$oid': '5e2a37a7b0dcdb1cdabf374c'},
#  {'$oid': '5e2a37a74594d0628545f80a'},
#  {'$oid': '5e2a37a73df4b79e01d1a341'},
#  {'$oid': '5e2a37a70307bc1dd7ae6457'},
#  {'$oid': '5e2a37a7669f5bfdb65ca022'},
#  {'$oid': '5e2a37a7f42c088c015249fa'},
#  {'$oid': '5e2a37a7b83edc60eb70ca94'},
# ...
